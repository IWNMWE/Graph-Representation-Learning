# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.12)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.1.31)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.6 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
import torch
import torch_geometric

# %%
# VGAE
class distrGCN(torch.nn.Module):
  def __init__(self, node_dim : int, latent_dim : int = 16):
    super(distrGCN, self).__init__()
    self.node_dim = node_dim
    self.latent_dim = latent_dim
    self.sharedConv = torch_geometric.nn.GCNConv(self.node_dim, self.latent_dim)
    self.avgConv = torch_geometric.nn.GCNConv(self.latent_dim, self.node_dim)
    self.varConv = torch_geometric.nn.GCNConv(self.latent_dim, self.node_dim)

  def forward(self, x, edge_index):
    x = self.sharedConv(x, edge_index)
    x = torch.relu(x)
    avg = self.avgConv(x, edge_index)
    log_var = self.varConv(x, edge_index)
    eps = torch.normal(mean=torch.zeros(avg.shape[0]), std=torch.ones(avg.shape[0]))
    embd = avg + (eps.reshape(log_var.shape[0], 1) * torch.exp(0.5 * log_var))
    return embd, avg, log_var

# %%
from torch_geometric.datasets import Planetoid
dataset = Planetoid(root='/tmp/Cora', name='Cora')
data = dataset[0]
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %%
model = distrGCN(node_dim=data.x.shape[1])
nodes = data.x.shape[0]
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
pos_weight = float(nodes * nodes - data.edge_index.shape[1]) / data.edge_index.shape[1]
lossfunc = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight))
m = torch.nn.Sigmoid()
for i in range(200):
  optimizer.zero_grad()
  out, avg, log_var = model(data.x, data.edge_index)
  adj_model = out @ out.t()
  adj_model = adj_model.flatten()
  adj = torch_geometric.utils.to_dense_adj(data.edge_index)[0]
  adj = adj.flatten()
  norm = nodes * nodes / float(2 * (nodes * nodes - adj.sum()))
  loss =  lossfunc(adj_model, adj)
  KLD = (-0.5   * torch.sum(1 + log_var - avg.pow(2) - log_var.exp())) / (nodes * nodes)
  loss = loss + KLD
  loss.backward()
  optimizer.step()
  adj = adj.detach()
  adj_model = adj_model.detach()
  print('Epoch ', i, ' : ', KLD)
  print('ROC AUC : ', roc_auc_score(adj, adj_model))
# Out:
# Epoch  0  :  tensor(2.5555e-05, grad_fn=<DivBackward0>)
# ROC AUC :  0.5040823860610839
# Epoch  1  :  tensor(0.0005, grad_fn=<DivBackward0>)
# ROC AUC :  0.4980659648236827
# Epoch  2  :  tensor(0.0024, grad_fn=<DivBackward0>)
# ROC AUC :  0.5040278869480066
# Epoch  3  :  tensor(0.0055, grad_fn=<DivBackward0>)
# ROC AUC :  0.5057491835226896
# Epoch  4  :  tensor(0.0117, grad_fn=<DivBackward0>)
# ROC AUC :  0.5058463457373666
# Epoch  5  :  tensor(0.0248, grad_fn=<DivBackward0>)
# ROC AUC :  0.5006766772987591
# Epoch  6  :  tensor(0.0497, grad_fn=<DivBackward0>)
# ROC AUC :  0.5161686561534755
# Epoch  7  :  tensor(0.0867, grad_fn=<DivBackward0>)
# ROC AUC :  0.5214554293462322
# Epoch  8  :  tensor(0.1373, grad_fn=<DivBackward0>)
# ROC AUC :  0.546985689135298
# Epoch  9  :  tensor(0.1976, grad_fn=<DivBackward0>)
# ROC AUC :  0.5456978051695544
# Epoch  10  :  tensor(0.2684, grad_fn=<DivBackward0>)
# ROC AUC :  0.5501992533422332
# Epoch  11  :  tensor(0.3518, grad_fn=<DivBackward0>)
# ROC AUC :  0.5326834216498901
# Epoch  12  :  tensor(0.4496, grad_fn=<DivBackward0>)
# ROC AUC :  0.5412629003272657
# Epoch  13  :  tensor(0.5554, grad_fn=<DivBackward0>)
# ROC AUC :  0.5852475892225801
# Epoch  14  :  tensor(0.6622, grad_fn=<DivBackward0>)
# ROC AUC :  0.6027744436635891
# Epoch  15  :  tensor(0.7669, grad_fn=<DivBackward0>)
# ROC AUC :  0.5911830080402385
# Epoch  16  :  tensor(0.8698, grad_fn=<DivBackward0>)
# ROC AUC :  0.6113896235615363
# Epoch  17  :  tensor(0.9702, grad_fn=<DivBackward0>)
# ROC AUC :  0.6583537937426698
# Epoch  18  :  tensor(1.0652, grad_fn=<DivBackward0>)
# ROC AUC :  0.6553476074127792
# Epoch  19  :  tensor(1.1562, grad_fn=<DivBackward0>)
# ROC AUC :  0.6696956778017531
# Epoch  20  :  tensor(1.2432, grad_fn=<DivBackward0>)
# ROC AUC :  0.6791556336038731
# Epoch  21  :  tensor(1.3236, grad_fn=<DivBackward0>)
# ROC AUC :  0.6627038428695085
# Epoch  22  :  tensor(1.3978, grad_fn=<DivBackward0>)
# ROC AUC :  0.6763977332510411
# Epoch  23  :  tensor(1.4669, grad_fn=<DivBackward0>)
# ROC AUC :  0.7167304278337425
# Epoch  24  :  tensor(1.5303, grad_fn=<DivBackward0>)
# ROC AUC :  0.713666335740183
# Epoch  25  :  tensor(1.5890, grad_fn=<DivBackward0>)
# ROC AUC :  0.7090946308276813
# Epoch  26  :  tensor(1.6442, grad_fn=<DivBackward0>)
# ROC AUC :  0.7198953639984087
# Epoch  27  :  tensor(1.6942, grad_fn=<DivBackward0>)
# ROC AUC :  0.7237550699331987
# Epoch  28  :  tensor(1.7394, grad_fn=<DivBackward0>)
# ROC AUC :  0.7219212487769981
# Epoch  29  :  tensor(1.7813, grad_fn=<DivBackward0>)
# ROC AUC :  0.7301679089505184
# Epoch  30  :  tensor(1.8198, grad_fn=<DivBackward0>)
# ROC AUC :  0.7353529132354022
# Epoch  31  :  tensor(1.8551, grad_fn=<DivBackward0>)
# ROC AUC :  0.7161651592346447
# Epoch  32  :  tensor(1.8871, grad_fn=<DivBackward0>)
# ROC AUC :  0.7187727444047624
# Epoch  33  :  tensor(1.9155, grad_fn=<DivBackward0>)
# ROC AUC :  0.721597111695822
# Epoch  34  :  tensor(1.9412, grad_fn=<DivBackward0>)
# ROC AUC :  0.7284808448746118
# Epoch  35  :  tensor(1.9647, grad_fn=<DivBackward0>)
# ROC AUC :  0.7330840209905942
# Epoch  36  :  tensor(1.9863, grad_fn=<DivBackward0>)
# ROC AUC :  0.730838425483348
# Epoch  37  :  tensor(2.0061, grad_fn=<DivBackward0>)
# ROC AUC :  0.722298720847841
# Epoch  38  :  tensor(2.0239, grad_fn=<DivBackward0>)
# ROC AUC :  0.7207476905142668
# Epoch  39  :  tensor(2.0396, grad_fn=<DivBackward0>)
# ROC AUC :  0.7227993111202611
# Epoch  40  :  tensor(2.0538, grad_fn=<DivBackward0>)
# ROC AUC :  0.7242561793230284
# Epoch  41  :  tensor(2.0665, grad_fn=<DivBackward0>)
# ROC AUC :  0.7228808842108031
# Epoch  42  :  tensor(2.0781, grad_fn=<DivBackward0>)
# ROC AUC :  0.726362836827399
# Epoch  43  :  tensor(2.0883, grad_fn=<DivBackward0>)
# ROC AUC :  0.7241195010792325
# Epoch  44  :  tensor(2.0975, grad_fn=<DivBackward0>)
# ROC AUC :  0.732714696412316
# Epoch  45  :  tensor(2.1058, grad_fn=<DivBackward0>)
# ROC AUC :  0.7318670783445311
# Epoch  46  :  tensor(2.1133, grad_fn=<DivBackward0>)
# ROC AUC :  0.7200951465798509
# Epoch  47  :  tensor(2.1199, grad_fn=<DivBackward0>)
# ROC AUC :  0.7168177785262739
# Epoch  48  :  tensor(2.1257, grad_fn=<DivBackward0>)
# ROC AUC :  0.7054454655348295
# Epoch  49  :  tensor(2.1307, grad_fn=<DivBackward0>)
# ROC AUC :  0.7120894667570353
# Epoch  50  :  tensor(2.1352, grad_fn=<DivBackward0>)
# ROC AUC :  0.7179323496202138
# Epoch  51  :  tensor(2.1391, grad_fn=<DivBackward0>)
# ROC AUC :  0.7176198247816353
# Epoch  52  :  tensor(2.1425, grad_fn=<DivBackward0>)
# ROC AUC :  0.7123589423287217
# Epoch  53  :  tensor(2.1455, grad_fn=<DivBackward0>)
# ROC AUC :  0.7200560537154459
# Epoch  54  :  tensor(2.1481, grad_fn=<DivBackward0>)
# ROC AUC :  0.7159997823247959
# Epoch  55  :  tensor(2.1502, grad_fn=<DivBackward0>)
# ROC AUC :  0.7122679473484045
# Epoch  56  :  tensor(2.1521, grad_fn=<DivBackward0>)
# ROC AUC :  0.7187121650965242
# Epoch  57  :  tensor(2.1536, grad_fn=<DivBackward0>)
# ROC AUC :  0.7104699753328406
# Epoch  58  :  tensor(2.1548, grad_fn=<DivBackward0>)
# ROC AUC :  0.7132628055717988
# Epoch  59  :  tensor(2.1558, grad_fn=<DivBackward0>)
# ROC AUC :  0.7185536229371742
# Epoch  60  :  tensor(2.1566, grad_fn=<DivBackward0>)
# ROC AUC :  0.7062383037208492
# Epoch  61  :  tensor(2.1572, grad_fn=<DivBackward0>)
# ROC AUC :  0.7194457683599333
# Epoch  62  :  tensor(2.1575, grad_fn=<DivBackward0>)
# ROC AUC :  0.7175580797199422
# Epoch  63  :  tensor(2.1577, grad_fn=<DivBackward0>)
# ROC AUC :  0.708658032361552
# Epoch  64  :  tensor(2.1578, grad_fn=<DivBackward0>)
# ROC AUC :  0.7179799470345385
# Epoch  65  :  tensor(2.1577, grad_fn=<DivBackward0>)
# ROC AUC :  0.7183786932294565
# Epoch  66  :  tensor(2.1574, grad_fn=<DivBackward0>)
# ROC AUC :  0.7134066013917413
# Epoch  67  :  tensor(2.1571, grad_fn=<DivBackward0>)
# ROC AUC :  0.7177932508121596
# Epoch  68  :  tensor(2.1565, grad_fn=<DivBackward0>)
# ROC AUC :  0.7233781440178042
# Epoch  69  :  tensor(2.1559, grad_fn=<DivBackward0>)
# ROC AUC :  0.7248275462677027
# Epoch  70  :  tensor(2.1553, grad_fn=<DivBackward0>)
# ROC AUC :  0.7220449656188677
# Epoch  71  :  tensor(2.1545, grad_fn=<DivBackward0>)
# ROC AUC :  0.7234422722950387
# Epoch  72  :  tensor(2.1537, grad_fn=<DivBackward0>)
# ROC AUC :  0.7243852300584388
# Epoch  73  :  tensor(2.1528, grad_fn=<DivBackward0>)
# ROC AUC :  0.7314228886579109
# Epoch  74  :  tensor(2.1517, grad_fn=<DivBackward0>)
# ROC AUC :  0.7315118451641507
# Epoch  75  :  tensor(2.1506, grad_fn=<DivBackward0>)
# ROC AUC :  0.7326293044510527
# Epoch  76  :  tensor(2.1494, grad_fn=<DivBackward0>)
# ROC AUC :  0.7287945326464094
# Epoch  77  :  tensor(2.1482, grad_fn=<DivBackward0>)
# ROC AUC :  0.7269066999803484
# Epoch  78  :  tensor(2.1471, grad_fn=<DivBackward0>)
# ROC AUC :  0.7325348084716184
# Epoch  79  :  tensor(2.1458, grad_fn=<DivBackward0>)
# ROC AUC :  0.7305800540590549
# Epoch  80  :  tensor(2.1446, grad_fn=<DivBackward0>)
# ROC AUC :  0.7251956597488297
# Epoch  81  :  tensor(2.1432, grad_fn=<DivBackward0>)
# ROC AUC :  0.7286029697064033
# Epoch  82  :  tensor(2.1417, grad_fn=<DivBackward0>)
# ROC AUC :  0.7429175481154444
# Epoch  83  :  tensor(2.1403, grad_fn=<DivBackward0>)
# ROC AUC :  0.7413176872647942
# Epoch  84  :  tensor(2.1388, grad_fn=<DivBackward0>)
# ROC AUC :  0.7391663724805569
# Epoch  85  :  tensor(2.1374, grad_fn=<DivBackward0>)
# ROC AUC :  0.7437885487439251
# Epoch  86  :  tensor(2.1359, grad_fn=<DivBackward0>)
# ROC AUC :  0.7460571805826639
# Epoch  87  :  tensor(2.1343, grad_fn=<DivBackward0>)
# ROC AUC :  0.7461235093164087
# Epoch  88  :  tensor(2.1327, grad_fn=<DivBackward0>)
# ROC AUC :  0.7518676830397916
# Epoch  89  :  tensor(2.1311, grad_fn=<DivBackward0>)
# ROC AUC :  0.7471810290616447
# Epoch  90  :  tensor(2.1295, grad_fn=<DivBackward0>)
# ROC AUC :  0.7482411984441316
# Epoch  91  :  tensor(2.1278, grad_fn=<DivBackward0>)
# ROC AUC :  0.7517329410947475
# Epoch  92  :  tensor(2.1262, grad_fn=<DivBackward0>)
# ROC AUC :  0.7534465179212283
# Epoch  93  :  tensor(2.1245, grad_fn=<DivBackward0>)
# ROC AUC :  0.7501750746134941
# Epoch  94  :  tensor(2.1228, grad_fn=<DivBackward0>)
# ROC AUC :  0.7576555758877767
# Epoch  95  :  tensor(2.1211, grad_fn=<DivBackward0>)
# ROC AUC :  0.7595173611162693
# Epoch  96  :  tensor(2.1193, grad_fn=<DivBackward0>)
# ROC AUC :  0.757329393864093
# Epoch  97  :  tensor(2.1175, grad_fn=<DivBackward0>)
# ROC AUC :  0.752878243313178
# Epoch  98  :  tensor(2.1158, grad_fn=<DivBackward0>)
# ROC AUC :  0.7643169254013727
# Epoch  99  :  tensor(2.1141, grad_fn=<DivBackward0>)
# ROC AUC :  0.7621221007462547
# Epoch  100  :  tensor(2.1123, grad_fn=<DivBackward0>)
# ROC AUC :  0.7628889463987429
# Epoch  101  :  tensor(2.1105, grad_fn=<DivBackward0>)
# ROC AUC :  0.7606518885727165
# Epoch  102  :  tensor(2.1087, grad_fn=<DivBackward0>)
# ROC AUC :  0.7678510825976841
# Epoch  103  :  tensor(2.1070, grad_fn=<DivBackward0>)
# ROC AUC :  0.7645701125081082
# Epoch  104  :  tensor(2.1052, grad_fn=<DivBackward0>)
# ROC AUC :  0.7644680989059837
# Epoch  105  :  tensor(2.1034, grad_fn=<DivBackward0>)
# ROC AUC :  0.7655130941917636
# Epoch  106  :  tensor(2.1016, grad_fn=<DivBackward0>)
# ROC AUC :  0.7630152479477593
# Epoch  107  :  tensor(2.0998, grad_fn=<DivBackward0>)
# ROC AUC :  0.7663716372055472
# Epoch  108  :  tensor(2.0980, grad_fn=<DivBackward0>)
# ROC AUC :  0.7701060001350778
# Epoch  109  :  tensor(2.0962, grad_fn=<DivBackward0>)
# ROC AUC :  0.7672459972909514
# Epoch  110  :  tensor(2.0944, grad_fn=<DivBackward0>)
# ROC AUC :  0.7723000333906791
# Epoch  111  :  tensor(2.0926, grad_fn=<DivBackward0>)
# ROC AUC :  0.7624566071740729
# Epoch  112  :  tensor(2.0909, grad_fn=<DivBackward0>)
# ROC AUC :  0.7671687132225218
# Epoch  113  :  tensor(2.0891, grad_fn=<DivBackward0>)
# ROC AUC :  0.7746170627756404
# Epoch  114  :  tensor(2.0873, grad_fn=<DivBackward0>)
# ROC AUC :  0.7759829806690703
# Epoch  115  :  tensor(2.0855, grad_fn=<DivBackward0>)
# ROC AUC :  0.7734982363601102
# Epoch  116  :  tensor(2.0837, grad_fn=<DivBackward0>)
# ROC AUC :  0.7637528887924564
# Epoch  117  :  tensor(2.0820, grad_fn=<DivBackward0>)
# ROC AUC :  0.7702883629489747
# Epoch  118  :  tensor(2.0803, grad_fn=<DivBackward0>)
# ROC AUC :  0.7793877778613794
# Epoch  119  :  tensor(2.0784, grad_fn=<DivBackward0>)
# ROC AUC :  0.7743265996184061
# Epoch  120  :  tensor(2.0766, grad_fn=<DivBackward0>)
# ROC AUC :  0.7761660448160596
# Epoch  121  :  tensor(2.0748, grad_fn=<DivBackward0>)
# ROC AUC :  0.7740100409761027
# Epoch  122  :  tensor(2.0731, grad_fn=<DivBackward0>)
# ROC AUC :  0.7796963587556675
# Epoch  123  :  tensor(2.0714, grad_fn=<DivBackward0>)
# ROC AUC :  0.7772760735582802
# Epoch  124  :  tensor(2.0695, grad_fn=<DivBackward0>)
# ROC AUC :  0.7761727183215261
# Epoch  125  :  tensor(2.0677, grad_fn=<DivBackward0>)
# ROC AUC :  0.7794210482070145
# Epoch  126  :  tensor(2.0659, grad_fn=<DivBackward0>)
# ROC AUC :  0.7803970894689708
# Epoch  127  :  tensor(2.0642, grad_fn=<DivBackward0>)
# ROC AUC :  0.7739587537621164
# Epoch  128  :  tensor(2.0624, grad_fn=<DivBackward0>)
# ROC AUC :  0.7778066773992753
# Epoch  129  :  tensor(2.0606, grad_fn=<DivBackward0>)
# ROC AUC :  0.7769894142650088
# Epoch  130  :  tensor(2.0588, grad_fn=<DivBackward0>)
# ROC AUC :  0.7833047700912005
# Epoch  131  :  tensor(2.0571, grad_fn=<DivBackward0>)
# ROC AUC :  0.7855167840048799
# Epoch  132  :  tensor(2.0554, grad_fn=<DivBackward0>)
# ROC AUC :  0.7872538944945892
# Epoch  133  :  tensor(2.0537, grad_fn=<DivBackward0>)
# ROC AUC :  0.7826322892383786
# Epoch  134  :  tensor(2.0519, grad_fn=<DivBackward0>)
# ROC AUC :  0.7806956444902683
# Epoch  135  :  tensor(2.0501, grad_fn=<DivBackward0>)
# ROC AUC :  0.7865120087683484
# Epoch  136  :  tensor(2.0484, grad_fn=<DivBackward0>)
# ROC AUC :  0.7828843787559787
# Epoch  137  :  tensor(2.0466, grad_fn=<DivBackward0>)
# ROC AUC :  0.7863514998827497
# Epoch  138  :  tensor(2.0450, grad_fn=<DivBackward0>)
# ROC AUC :  0.7882123389351244
# Epoch  139  :  tensor(2.0433, grad_fn=<DivBackward0>)
# ROC AUC :  0.7895492306399988
# Epoch  140  :  tensor(2.0416, grad_fn=<DivBackward0>)
# ROC AUC :  0.7883793702754038
# Epoch  141  :  tensor(2.0399, grad_fn=<DivBackward0>)
# ROC AUC :  0.7949276384179342
# Epoch  142  :  tensor(2.0382, grad_fn=<DivBackward0>)
# ROC AUC :  0.7956901798733722
# Epoch  143  :  tensor(2.0366, grad_fn=<DivBackward0>)
# ROC AUC :  0.7908856021666412
# Epoch  144  :  tensor(2.0350, grad_fn=<DivBackward0>)
# ROC AUC :  0.7979690096712231
# Epoch  145  :  tensor(2.0333, grad_fn=<DivBackward0>)
# ROC AUC :  0.7895432132662332
# Epoch  146  :  tensor(2.0316, grad_fn=<DivBackward0>)
# ROC AUC :  0.8005623034395765
# Epoch  147  :  tensor(2.0299, grad_fn=<DivBackward0>)
# ROC AUC :  0.7972427128362536
# Epoch  148  :  tensor(2.0283, grad_fn=<DivBackward0>)
# ROC AUC :  0.7996159681982058
# Epoch  149  :  tensor(2.0267, grad_fn=<DivBackward0>)
# ROC AUC :  0.8055716246257232
# Epoch  150  :  tensor(2.0249, grad_fn=<DivBackward0>)
# ROC AUC :  0.8024434391327057
# Epoch  151  :  tensor(2.0233, grad_fn=<DivBackward0>)
# ROC AUC :  0.8059215668111928
# Epoch  152  :  tensor(2.0216, grad_fn=<DivBackward0>)
# ROC AUC :  0.8022232448630067
# Epoch  153  :  tensor(2.0199, grad_fn=<DivBackward0>)
# ROC AUC :  0.803370648286352
# Epoch  154  :  tensor(2.0183, grad_fn=<DivBackward0>)
# ROC AUC :  0.8073081603436486
# Epoch  155  :  tensor(2.0167, grad_fn=<DivBackward0>)
# ROC AUC :  0.8040058694538038
# Epoch  156  :  tensor(2.0151, grad_fn=<DivBackward0>)
# ROC AUC :  0.8088209901198478
# Epoch  157  :  tensor(2.0134, grad_fn=<DivBackward0>)
# ROC AUC :  0.8138417314491471
# Epoch  158  :  tensor(2.0118, grad_fn=<DivBackward0>)
# ROC AUC :  0.8152772179837161
# Epoch  159  :  tensor(2.0103, grad_fn=<DivBackward0>)
# ROC AUC :  0.8087544932327875
# Epoch  160  :  tensor(2.0089, grad_fn=<DivBackward0>)
# ROC AUC :  0.8172231983198042
# Epoch  161  :  tensor(2.0075, grad_fn=<DivBackward0>)
# ROC AUC :  0.8236448052815274
# Epoch  162  :  tensor(2.0062, grad_fn=<DivBackward0>)
# ROC AUC :  0.8239381025168354
# Epoch  163  :  tensor(2.0048, grad_fn=<DivBackward0>)
# ROC AUC :  0.8300671239387684
# Epoch  164  :  tensor(2.0034, grad_fn=<DivBackward0>)
# ROC AUC :  0.837439043864296
# Epoch  165  :  tensor(2.0021, grad_fn=<DivBackward0>)
# ROC AUC :  0.8337009509144034
# Epoch  166  :  tensor(2.0007, grad_fn=<DivBackward0>)
# ROC AUC :  0.8396596489660509
# Epoch  167  :  tensor(1.9994, grad_fn=<DivBackward0>)
# ROC AUC :  0.8441272231979849
# Epoch  168  :  tensor(1.9982, grad_fn=<DivBackward0>)
# ROC AUC :  0.8452338687441426
# Epoch  169  :  tensor(1.9965, grad_fn=<DivBackward0>)
# ROC AUC :  0.8530008916634988
# Epoch  170  :  tensor(1.9954, grad_fn=<DivBackward0>)
# ROC AUC :  0.8450899897919331
# Epoch  171  :  tensor(1.9939, grad_fn=<DivBackward0>)
# ROC AUC :  0.8508018430974883
# Epoch  172  :  tensor(1.9923, grad_fn=<DivBackward0>)
# ROC AUC :  0.8496707940006515
# Epoch  173  :  tensor(1.9910, grad_fn=<DivBackward0>)
# ROC AUC :  0.8520037275869901
# Epoch  174  :  tensor(1.9896, grad_fn=<DivBackward0>)
# ROC AUC :  0.8511163440286019
# Epoch  175  :  tensor(1.9879, grad_fn=<DivBackward0>)
# ROC AUC :  0.8592345396746811
# Epoch  176  :  tensor(1.9865, grad_fn=<DivBackward0>)
# ROC AUC :  0.8567593454985959
# Epoch  177  :  tensor(1.9851, grad_fn=<DivBackward0>)
# ROC AUC :  0.8539174319304301
# Epoch  178  :  tensor(1.9831, grad_fn=<DivBackward0>)
# ROC AUC :  0.8642135875718372
# Epoch  179  :  tensor(1.9817, grad_fn=<DivBackward0>)
# ROC AUC :  0.8605387430115354
# Epoch  180  :  tensor(1.9803, grad_fn=<DivBackward0>)
# ROC AUC :  0.8514598305006548
# Epoch  181  :  tensor(1.9783, grad_fn=<DivBackward0>)
# ROC AUC :  0.8690120224690014
# Epoch  182  :  tensor(1.9765, grad_fn=<DivBackward0>)
# ROC AUC :  0.867583813306683
# Epoch  183  :  tensor(1.9752, grad_fn=<DivBackward0>)
# ROC AUC :  0.856945707458368
# Epoch  184  :  tensor(1.9735, grad_fn=<DivBackward0>)
# ROC AUC :  0.8590016706192043
# Epoch  185  :  tensor(1.9716, grad_fn=<DivBackward0>)
# ROC AUC :  0.8664622984821301
# Epoch  186  :  tensor(1.9701, grad_fn=<DivBackward0>)
# ROC AUC :  0.8674674264642132
# Epoch  187  :  tensor(1.9688, grad_fn=<DivBackward0>)
# ROC AUC :  0.8670416653356621
# Epoch  188  :  tensor(1.9673, grad_fn=<DivBackward0>)
# ROC AUC :  0.8649249735622779
# Epoch  189  :  tensor(1.9656, grad_fn=<DivBackward0>)
# ROC AUC :  0.8731086793881144
# Epoch  190  :  tensor(1.9641, grad_fn=<DivBackward0>)
# ROC AUC :  0.872424557741044
# Epoch  191  :  tensor(1.9629, grad_fn=<DivBackward0>)
# ROC AUC :  0.8697191437586278
# Epoch  192  :  tensor(1.9614, grad_fn=<DivBackward0>)
# ROC AUC :  0.8674510183591746
# Epoch  193  :  tensor(1.9597, grad_fn=<DivBackward0>)
# ROC AUC :  0.8726492269743549
# Epoch  194  :  tensor(1.9582, grad_fn=<DivBackward0>)
# ROC AUC :  0.8767065992789137
# Epoch  195  :  tensor(1.9568, grad_fn=<DivBackward0>)
# ROC AUC :  0.8756080754939047
# Epoch  196  :  tensor(1.9554, grad_fn=<DivBackward0>)
# ROC AUC :  0.866983434378126
# Epoch  197  :  tensor(1.9538, grad_fn=<DivBackward0>)
# ROC AUC :  0.8772696591289735
# Epoch  198  :  tensor(1.9522, grad_fn=<DivBackward0>)
# ROC AUC :  0.880310402970392
# Epoch  199  :  tensor(1.9509, grad_fn=<DivBackward0>)
# ROC AUC :  0.8778285901670037

# %%
out, avg, log_var = model(data.x, data.edge_index)

# %%
# GAE
# note the increased latent dimension.
from torch_geometric.nn import BatchNorm
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from sklearn.metrics import roc_auc_score
class GAE(torch.nn.Module):
    def __init__(self, node_dim: int, latent_dim: int = 64):
        super(GAE, self).__init__()
        self.conv1 = GCNConv(node_dim, latent_dim)
        self.conv2 = GCNConv(latent_dim, latent_dim)
        self.conv3 = GCNConv(latent_dim, node_dim)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        ##x = self.conv2(x, edge_index)
        ##x = F.relu(x)
        embd = self.conv3(x, edge_index)
        x = F.relu(embd)
        return embd

# %%
model = GAE(node_dim=data.x.shape[1])
nodes = data.x.shape[0]
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
pos_weight = float(nodes * nodes - data.edge_index.shape[1]) / data.edge_index.shape[1]
lossfunc = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight))
for i in range(200):
  optimizer.zero_grad()
  out = model(data.x, data.edge_index)
  adj_model = out @ out.t()
  adj_model = adj_model.flatten()
  adj = torch_geometric.utils.to_dense_adj(data.edge_index)[0]
  adj = adj.flatten()
  #norm = nodes * nodes / float(2 * (nodes * nodes - adj.sum()))
  loss =  lossfunc(adj_model, adj)
  loss.backward()
  optimizer.step()
  with torch.no_grad():
    print('ROC AUC : ', roc_auc_score(adj, adj_model))
# Out:
# ROC AUC :  0.880918436341878
# ROC AUC :  0.8492859534173747
# ROC AUC :  0.7688261576572621
# ROC AUC :  0.8039718674122641
# ROC AUC :  0.9540884197534049
# ROC AUC :  0.8953222402403664
# ROC AUC :  0.7946112417257215
# ROC AUC :  0.7510015060750661
# ROC AUC :  0.735035041475864
# ROC AUC :  0.7288434271621355
# ROC AUC :  0.7257834510343031
# ROC AUC :  0.7230532124063916
# ROC AUC :  0.719777158453251
# ROC AUC :  0.7162996657676344
# ROC AUC :  0.71347041526445
# ROC AUC :  0.7126673904649456
# ROC AUC :  0.7145762046621031
# ROC AUC :  0.7198685926787999
# ROC AUC :  0.7275064452291259
# ROC AUC :  0.7355174428714334
# ROC AUC :  0.742427222705111
# ROC AUC :  0.7475982057939721
# ROC AUC :  0.7507004339029081
# ROC AUC :  0.7534725784767734
# ROC AUC :  0.7587836192473348
# ROC AUC :  0.7680855868335429
# ROC AUC :  0.7811970068604089
# ROC AUC :  0.7953463836799372
# ROC AUC :  0.8048807261206058
# ROC AUC :  0.8104016797590032
# ROC AUC :  0.8134133313433187
# ROC AUC :  0.8151487241930958
# ROC AUC :  0.8168418988657862
# ROC AUC :  0.8195342103180627
# ROC AUC :  0.8231897245822941
# ROC AUC :  0.8271179584524639
# ROC AUC :  0.8311933705494913
# ROC AUC :  0.8360518359667943
# ROC AUC :  0.8422345610465816
# ROC AUC :  0.8494614359688973
# ROC AUC :  0.8570827204951816
# ROC AUC :  0.8643302431129037
# ROC AUC :  0.871090253964595
# ROC AUC :  0.8775085813803827
# ROC AUC :  0.8833601075025015
# ROC AUC :  0.8882930116486228
# ROC AUC :  0.8924844682529118
# ROC AUC :  0.8965283865198893
# ROC AUC :  0.9008843651015882
# ROC AUC :  0.9053949963754675
# ROC AUC :  0.9094897552242525
# ROC AUC :  0.9129358188805541
# ROC AUC :  0.9157937006875578
# ROC AUC :  0.9179576652958996
# ROC AUC :  0.9193289631833736
# ROC AUC :  0.9202449706780391
# ROC AUC :  0.9212473912791935
# ROC AUC :  0.9226618884558648
# ROC AUC :  0.9245042128424252
# ROC AUC :  0.9266196890295669
# ROC AUC :  0.9288584796575263
# ROC AUC :  0.931133838016987
# ROC AUC :  0.9333981503802437
# ROC AUC :  0.9355811182472862
# ROC AUC :  0.9375629822524922
# ROC AUC :  0.9393074423409453
# ROC AUC :  0.9408867906605097
# ROC AUC :  0.9423929148478275
# ROC AUC :  0.9438191267011595
# ROC AUC :  0.9450915544948856
# ROC AUC :  0.9461865886522779
# ROC AUC :  0.9471793585946816
# ROC AUC :  0.9481523015561208
# ROC AUC :  0.9491354186728485
# ROC AUC :  0.9501108614756282
# ROC AUC :  0.9510447440053724
# ROC AUC :  0.9519157209335237
# ROC AUC :  0.9526958854075258
# ROC AUC :  0.9533811729697617
# ROC AUC :  0.9540239796719545
# ROC AUC :  0.9547126049765934
# ROC AUC :  0.9554912869898539
# ROC AUC :  0.9563051655890923
# ROC AUC :  0.9570950725476826
# ROC AUC :  0.9578700558219102
# ROC AUC :  0.9586526655695745
# ROC AUC :  0.9594227141688456
# ROC AUC :  0.9601687970913619
# ROC AUC :  0.9608953552250435
# ROC AUC :  0.9615807413079425
# ROC AUC :  0.9621990322257206
# ROC AUC :  0.9627511911923423
# ROC AUC :  0.9632652061744809
# ROC AUC :  0.9637767147951012
# ROC AUC :  0.9643005143130939
# ROC AUC :  0.9648386672909722
# ROC AUC :  0.9653875192855138
# ROC AUC :  0.965947426474368
# ROC AUC :  0.9665169104266251
# ROC AUC :  0.9670944309508032
# ROC AUC :  0.967676821704966
# ROC AUC :  0.9682552165086586
# ROC AUC :  0.9688191648623111
# ROC AUC :  0.9693616149090293
# ROC AUC :  0.9698733013079891
# ROC AUC :  0.970342947023591
# ROC AUC :  0.9707827339989665
# ROC AUC :  0.9712081919715922
# ROC AUC :  0.9716154851687385
# ROC AUC :  0.9719953722992055
# ROC AUC :  0.9723494133672776
# ROC AUC :  0.9726856884968174
# ROC AUC :  0.9730083000116319
# ROC AUC :  0.9733133833868189
# ROC AUC :  0.973598749304505
# ROC AUC :  0.973875265478017
# ROC AUC :  0.974149278524226
# ROC AUC :  0.9744168582765977
# ROC AUC :  0.9746750398136493
# ROC AUC :  0.9749279346637648
# ROC AUC :  0.975183926908817
# ROC AUC :  0.9754397137553316
# ROC AUC :  0.975692256257109
# ROC AUC :  0.9759476718157215
# ROC AUC :  0.9762091456932638
# ROC AUC :  0.976465485991616
# ROC AUC :  0.9767137097811855
# ROC AUC :  0.9769614649200391
# ROC AUC :  0.9772052220255879
# ROC AUC :  0.9774327991935102
# ROC AUC :  0.9776453362647287
# ROC AUC :  0.9778528031861855
# ROC AUC :  0.9780496051019856
# ROC AUC :  0.9782281563544878
# ROC AUC :  0.9783920119283287
# ROC AUC :  0.9785494436781145
# ROC AUC :  0.9786992143612985
# ROC AUC :  0.9788389586540174
